# %% [markdown]
# # This is a practice Dataset made to Practice Decision Trees

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv(r'C:\Users\vchan\OneDrive\Desktop\Machine Learning\datasets\customer_purchase_data.csv')
df
# Out:
#      age  income  time_on_site  pages_viewed  previous_purchases  bought
# 0     56       7            16             1                   1       0
# 1     46       6            13            14                   9       1
# 2     32      21            18             1                   2       0
# 3     25       3            10             5                   2       0
# 4     38       7            19             6                   4       1
# ..   ...     ...           ...           ...                 ...     ...
# 195   23      16             3             9                   1       0
# 196   49       4            19             3                   4       0
# 197   21      24            18             3                   7       0
# 198   28       9            15            11                   7       1
# 199   34      21             9            13                   2       1
#
# [200 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 200 non-null    int64
#  1   income              200 non-null    int64
#  2   time_on_site        200 non-null    int64
#  3   pages_viewed        200 non-null    int64
#  4   previous_purchases  200 non-null    int64
#  5   bought              200 non-null    int64
# dtypes: int64(6)
# memory usage: 9.5 KB

# %%
df.describe(include='all')
# Out:
#               age      income  time_on_site  pages_viewed  previous_purchases  \
# count  200.000000  200.000000    200.000000    200.000000          200.000000
# mean    38.665000   12.825000     10.205000      7.035000            4.545000
# std     12.604648    7.227417      5.625049      4.109527            2.913834
# min     18.000000    2.000000      1.000000      1.000000            0.000000
# 25%     27.750000    6.000000      5.000000      3.000000            2.000000
# 50%     40.000000   13.000000     10.000000      7.000000            5.000000
# 75%     49.250000   19.250000     15.250000     11.000000            7.000000
# max     59.000000   24.000000     19.000000     14.000000            9.000000
#
#            bought
# count  200.000000
# mean     0.335000
# std      0.473175
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000

# %%
df['bought'].value_counts().plot(kind='bar')
plt.title('Bought vs Not Bought')
plt.xticks(rotation=0)
plt.ylabel('No. of People')
plt.show()

# %%
df.groupby('bought')['income'].mean().plot(kind='bar')
plt.title('Income Split')
plt.xticks(rotation=0)
plt.ylabel('No. of People')
plt.show()

# %%
df.groupby('bought')['time_on_site'].mean().plot(kind='bar')
plt.title('Time Split')
plt.xticks(rotation=0)
plt.ylabel('No. of People')
plt.show()

# %%
df.groupby('bought')['previous_purchases'].mean().plot(kind='bar')
plt.title('Previous purchase split')
plt.xticks(rotation=0)
plt.ylabel('No. of People')
plt.show()

# %%
X = df.drop('bought',axis=1)
y = df['bought']

# %%
X.head()
# Out:
#    age  income  time_on_site  pages_viewed  previous_purchases
# 0   56       7            16             1                   1
# 1   46       6            13            14                   9
# 2   32      21            18             1                   2
# 3   25       3            10             5                   2
# 4   38       7            19             6                   4

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    1
# Name: bought, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42,test_size=0.2,stratify=y)

# %%
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
acc = model.score(X_train,y_train)
acc
# Out:
# 1.0

# %%
acc2 = model.score(X_test,y_test)
acc2
# Out:
# 1.0

# %%
model.get_depth(), model.get_n_leaves()
# Out:
# (3, np.int64(4))
